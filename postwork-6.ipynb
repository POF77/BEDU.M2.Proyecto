# %%
print('hello, world')
endpoint = "https://www.climatewatchdata.org/api/v1/data/historical_emissions"
import requests as api
historical_emissions = api.get(endpoint)
# Out:
# hello, world

# %%
historical_emissions
# Out:
# <Response [200]>

# %%
sample_object = {'Name':'John', 'Location':{'City':'Los Angeles','State':'CA'}}
sample_object = {'Name':'John', 'Location':{'City':'Los Angeles','State':'CA'}, 'hobbies':['Music', 'Running']}
from pandas.io.json import json_normalize
json_normalize(sample_object)

def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

flat = flatten_json(sample_object)
f = json_normalize(flat)
f
# Out:
# C:\Users\ecardoz\AppData\Local\Temp/ipykernel_7388/784978697.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   json_normalize(sample_object)
# C:\Users\ecardoz\AppData\Local\Temp/ipykernel_7388/784978697.py:25: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   f = json_normalize(flat)
#    Name Location_City Location_State hobbies_0 hobbies_1
# 0  John   Los Angeles             CA     Music   Running

# %%
historial_emision_data = historical_emissions.json()['data']

# %% [markdown]
# Aplanado de JSON:
# json_struct = json.loads(df.to_json(orient="records"))
# df_flat = pf.io.json.json_normalize(json_struct)

# %%
historial_emision_data 
import pandas as pd
normalized = pd.json_normalize(historial_emision_data)
normalized
# Out:
#         id iso_code3      country data_source                        sector  \
# 0   653012       AFG  Afghanistan        CAIT          Total excluding LUCF
# 1   653013       AFG  Afghanistan        CAIT          Total including LUCF
# 2   653014       AFG  Afghanistan        CAIT                        Energy
# 3   653015       AFG  Afghanistan        CAIT          Industrial Processes
# 4   653016       AFG  Afghanistan        CAIT                   Agriculture
# 5   653017       AFG  Afghanistan        CAIT                         Waste
# 6   653018       AFG  Afghanistan        CAIT  Land-Use Change and Forestry
# 7   653019       AFG  Afghanistan        CAIT                  Bunker Fuels
# 8   653020       AFG  Afghanistan        CAIT              Electricity/Heat
# 9   653021       AFG  Afghanistan        CAIT    Manufacturing/Construction
# 10  653022       AFG  Afghanistan        CAIT                Transportation
# ...

# %%
#normalized = pd.json_normalize(historial_emision_data, record_path=['emissions'], meta=['id', 'iso_code3', 'country', 'data_source', 'sector', 'gas', 'unit'])
#normalized
